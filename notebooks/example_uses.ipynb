# %% [markdown]
# # POSEIDON Examples
#
# <p align="center">
#   <img src="../docs/logo.png" alt="Example image" width=350>
# </p>
#
# The **Photogrammetric Observation and Segmentation for Estimation of Inundation Depth ON-demand (POSEIDON)** methods were developed as part of [The Sunny Day Flooding Project](https://sunnydayflooding.com/) at NC State University. This notebook contains examples for using its methods.

# %% [markdown]
# ### Import Necessary Packages

# %%
import os

import numpy as np
import matplotlib.pyplot as plt

import poseidon_core
import poseidon_utils
# Out:
#  Platform does not have any supported GPU!
#  Platform verification failed
#  platform is not supported by cufile
#  cuFile initialization failed

# %% [markdown]
# ## Creating Flood Event Summaries
#
# To create the abbreviated flood event and flood event csvs, we use the EventTracker from poseidon_utils. This provides summary information, detailed timesteps, and plots for flood events for the desired sensor and observation window from the [Sunny Day Flooding Project sensors](https://data.sunnydayflooding.com/).

# %% [markdown]
# ### Import Additional Packages

# %%
from datetime import datetime

# Currently importing the SDFP API information from a local file.
from mysecrets import API_USERNAME, API_PASSWORD

# %% [markdown]
# ### Set API Credentials and Desired Data Details

# %%
# DO NOT SHARE THESE DETAILS PUBLICLY
authorization = (API_USERNAME, API_PASSWORD)
# DO NOT SHARE THESE DETAILS PUBLICLY

# Choose sensor location or provide sensor ID strings
# (e.g. 'Beaufort' or ['BF_01']
location = ["CB_03"]

# Dates proveided in year, month, day
start_date = datetime(2022, 3, 30)
end_date = datetime(2024, 8, 15)

# %% [markdown]
# ### Run Desired Method

# %%
# Initialize class
tracker = poseidon_utils.EventTracker(authorization, start_date, end_date)

# To pull data and create the csvs and plots
flood_data = tracker.pull_data_gen_csvs_and_plots(location)
# Alternatively, you can just fetch the raw data
# flood_data = tracker.get_data(location)
# Out:
# EventTracker initialized. Max workers: 4, Timeout: 60s
# Date Range Set: 2022-03-30 00:00:00 to 2024-08-15 00:00:00
# Starting data pull for location: '['CB_03']'
# Total date range split into 29 chunks of ~30 days each.
# Starting chunked download for 1 sensors... (29 total requests)
# Task failed, queueing for 1-day fallback: CB_03 (2022-03-30 00:00:00 to 2022-04-28 00:00:00)
# Task failed, queueing for 1-day fallback: CB_03 (2022-04-29 00:00:00 to 2022-05-28 00:00:00)
# Task failed, queueing for 1-day fallback: CB_03 (2023-04-24 00:00:00 to 2023-05-23 00:00:00)
# Task failed, queueing for 1-day fallback: CB_03 (2023-03-25 00:00:00 to 2023-04-23 00:00:00)
# Handling 4 failed chunks by fetching 1-day increments...
# Queueing 1-day fallback for CB_03 from 2023-03-25 00:00:00 to 2023-04-23 00:00:00
# Queueing 1-day fallback for CB_03 from 2022-04-29 00:00:00 to 2022-05-28 00:00:00
# Queueing 1-day fallback for CB_03 from 2023-04-24 00:00:00 to 2023-05-23 00:00:00
# Queueing 1-day fallback for CB_03 from 2022-03-30 00:00:00 to 2022-04-28 00:00:00
# Total fallback 1-day requests: 120
# Fallback data retrieval complete.
# Data retrieval complete.
# Combining 25 DataFrame chunks...
# Dropping duplicates and sorting by date...
# Final DataFrame shape: (366551, 20)
# Data pull successful. Shape: (366551, 20)
# Caching raw data to data/raw_sensor_data.parquet...
# Raw data cached successfully.
# Generating CSVs...
# CSV files created successfully.
# Checking for sensor outages...
# Sensor outage logs generated and CSVs appended.
# Plotting flood events...
# Folder data/flood_plots created successfully.
# Plotting completed.

# %%
# If abbr_flood_events.csv contains events that you need to merge or remove, 
# you can adjust the UTC timestamps or delete full rows and then regenerate 
# the updated products (plots and csvs) after altering abbr_flood_events.csv.
tracker.regenerate_outputs_from_csv()
# Out:
# --- Starting Regeneration Process ---
# Loading manually-edited events from: data/abbr_flood_events.csv
# Loading cached raw data from: data/raw_sensor_data.parquet
# Raw data and event CSVs loaded successfully.
# Recalculating event summaries (duration, max levels)...
# Re-numbering and cleaning flood events...
# Cleaned and recalculated event file saved to data/abbr_flood_events.csv
# Regenerating detailed event file: data/flood_events.csv...
# Successfully regenerated detailed event file: data/flood_events.csv
# Re-checking outages for data/sensor_outages.csv...
# Outage check complete.
# Regenerating plots in data/flood_plots (forcing overwrite)...
# Plot already exists (overwriting): data/flood_plots/flood_event_1_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_2_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_3_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_4_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_5_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_6_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_7_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_8_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_9_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_10_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_11_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_12_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_13_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_14_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_15_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_16_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_17_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_18_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_19_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_20_CB_03.png
# Plot already exists (overwriting): data/flood_plots/flood_event_21_CB_03.png
# Plotting completed.
# --- Regeneration Complete ---

# %%
flood_data.head()
# Out:
#    sensor_water_depth  min_water_depth  qa_qc_flag  deriv  \
# 0            0.337673         0.308632       False    0.0
# 1            0.336355         0.308632       False    0.0
# 2            0.338640         0.308632       False    0.0
# 3            0.346898         0.308632       False    0.0
# 4            0.413458         0.308632       False    0.0
#
#               date_surveyed change_pt  sensor_elevation  \
# 0 2022-02-21 00:00:00+00:00     False              0.59
# 1 2022-02-21 00:00:00+00:00     False              0.59
# 2 2022-02-21 00:00:00+00:00     False              0.59
# 3 2022-02-21 00:00:00+00:00     False              0.59
# 4 2022-02-21 00:00:00+00:00     False              0.59
#
#    smoothed_min_water_depth sensor_ID  road_elevation  sensor_water_level  \
# 0                  0.275222     CB_01            2.38            0.927673
# 1                  0.275222     CB_01            2.38            0.926355
# 2                  0.275222     CB_01            2.38            0.928640
# 3                  0.275222     CB_01            2.38            0.936898
# 4                  0.275222     CB_01            2.38            1.003458
#
#                             place       lat  road_water_level  \
# 0  Carolina Beach, North Carolina  34.05172         -1.452327
# 1  Carolina Beach, North Carolina  34.05172         -1.453645
# 2  Carolina Beach, North Carolina  34.05172         -1.451360
# 3  Carolina Beach, North Carolina  34.05172         -1.443102
# 4  Carolina Beach, North Carolina  34.05172         -1.376542
#
#                        date      lng  sensor_water_level_adj  voltage  \
# 0 2022-03-30 00:01:16+00:00 -77.8855                0.652451     4.33
# 1 2022-03-30 00:07:16+00:00 -77.8855                0.651132     4.34
# 2 2022-03-30 00:13:16+00:00 -77.8855                0.653418     4.34
# 3 2022-03-30 00:19:16+00:00 -77.8855                0.661676     4.34
# 4 2022-03-30 00:25:16+00:00 -77.8855                0.728235     4.34
#
#    alert_threshold  road_water_level_adj
# 0             1.88             -1.727549
# 1             1.88             -1.728868
# 2             1.88             -1.726582
# 3             1.88             -1.718324
# 4             1.88             -1.651765

# %%
import pandas as pd
from astral import LocationInfo
from astral.sun import sun, elevation
import pytz

# --- 1. CONFIGURATION ---
# DOUBLE CHECK SIGNS: North is (+), West is (-)
# Beaufort, NC is approx Lat 34.7, Lon -76.6

LAT = 34.05172
LON = -77.8855

FILE_PATH = 'data/carolina_beach/abbr_flood_events.csv'

# Define Location (Timezone doesn't matter for elevation, but we use UTC for consistency)
location = LocationInfo("Study Site", "NC", "UTC", LAT, LON)

# --- 2. LOAD DATA ---
df = pd.read_csv(FILE_PATH)

# Convert to datetime and force UTC
df['start_time_UTC'] = pd.to_datetime(df['start_time_UTC'])
df['end_time_UTC'] = pd.to_datetime(df['end_time_UTC'])

if df['start_time_UTC'].dt.tz is None:
    df['start_time_UTC'] = df['start_time_UTC'].dt.tz_localize('UTC')
if df['end_time_UTC'].dt.tz is None:
    df['end_time_UTC'] = df['end_time_UTC'].dt.tz_localize('UTC')

# --- 3. ROBUST ELEVATION CHECK ---
def check_daylight_physics(row):
    """
    Calculates the actual sun position for the Start and End times.
    If the sun is above the horizon (> 0 degrees) at either point, 
    OR if the event straddles the entire day, it counts.
    """
    start = row['start_time_UTC']
    end = row['end_time_UTC']
    
    try:
        # Check Sun Elevation at Start and End
        # elevation() returns degrees. >0 is Day, -6 is Civil Twilight, <-18 is Dark Night
        elev_start = elevation(location.observer, start)
        elev_end = elevation(location.observer, end)
        
        # Condition 1: Event starts or ends during the day
        if elev_start > 0 or elev_end > 0:
            return True
            
        # Condition 2: Event starts in dark, ends in dark, but crosses noon 
        # (Massive event straddling the whole day)
        # We check the midpoint of the event just to be safe
        midpoint = start + (end - start) / 2
        elev_mid = elevation(location.observer, midpoint)
        
        if elev_mid > 0:
            return True
            
        return False

    except Exception as e:
        # If calculation fails, print why (helps debugging)
        return False

# --- 4. APPLY FILTER ---
print("Calculating sun physics (elevation)...")
df['is_daylight'] = df.apply(check_daylight_physics, axis=1)

# Filter
daylight_df = df[df['is_daylight'] == True].copy()

# --- 5. VERIFICATION (DEBUGGING) ---
# Let's print the specific 1-3 PM cases to verify they are caught now
print(f"\nTotal Rows: {len(df)}")
print(f"Daylight Rows: {len(daylight_df)}")

# Sanity Check: Print the first 5 'Daylight' events to see if they make sense
print("\nSample of Captured Daylight Events (UTC):")
print(daylight_df[['start_time_UTC', 'end_time_UTC']].head())

# Optional: Save
daylight_df.to_csv('data/daylight_verified.csv', index=False)
# Out:
# Calculating sun physics (elevation)...
#
# Total Rows: 48
# Daylight Rows: 25
#
# Sample of Captured Daylight Events (UTC):
#               start_time_UTC              end_time_UTC
# 6  2022-08-19 16:32:26+00:00 2022-08-19 16:53:26+00:00
# 7  2022-08-19 16:56:26+00:00 2022-08-19 17:01:26+00:00
# 8  2022-08-19 17:04:26+00:00 2022-08-19 17:05:26+00:00
# 9  2022-08-19 17:07:26+00:00 2022-08-19 17:08:26+00:00
# 11 2022-09-29 15:26:27+00:00 2022-09-29 18:02:27+00:00

# %% [markdown]
# ## HPC Processing
#
# Most of the POSEIDON workflow has been set to run on the NC State University Hazel cluster. Jobs on the HPC system are managed using IBM Spectrum LSF (Load Sharing Facility), which handles resource allocation, queue management, and job scheduling across compute nodes. Submission dcripts are provided in poseidon/poseidon_deploy/hpc_submission_scripts, but would need to be adjusted for a SLURM-based job scheduling system.

# %% [markdown]
# **Submission Script Descriptions:**
# - For Segmentation Products:
#
#     - **create_job_lists.csh**
#
#         This script takes a folder of files and creates a directory containing a specified number of text files splitting that folder into batches.
#     - **make_overlays.csh**
#
#         This submission script deploys the overlay_generator executable on the job file lists to create overlays from original image-segmentation prediction pairs.
#     - **make_labels.csh**
#
#         This submission script deploys the pred_label_generator executable on the job file lists to create grayscale labels for future rectification or processing from segmentation predictions.
# - For File Organization/Preparation:
#
#     - **pull_and_save_images.csh**
#
#         This script pulls images from the image archive corresponding to a provided abbreviated flood event csv.
#     - **filter_images.csh**
#
#         This script filters images in a directory to a specified time window in Eastern time and copies those images to a directory.
#     - **flood_event_setup.csh**
#
#         This script is for preparation for the rectification and depth map processing steps of POSEIDON. It creates the flood event subfolders for each flood event in abbr_flood_events.csv filtered to a provided window in Eastern time, copies the appropriate images, and creates csvs for each event containing water level time series from the Sunny Day Flooding Sensors (SuDS).

# %% [markdown]
# ## Photogrammetric Methods

# %% [markdown]
# ### Elevation Grid Generation from Aerial LiDAR

# %%
# file_path = '/home/rmccune/Documents/poseidon/data/lidar/combined_point_cloud_down_east.laz'
file_path = "data/lidar/Job1051007_34077_04_88.laz"

# min_x_extent = 847809.694
# max_x_extent = 847973.874
# min_y_extent = 127254.634
# max_y_extent = 127450.141

min_x_extent = 712160
max_x_extent = 712230
min_y_extent = 33100
max_y_extent = 33170

grid_gen = poseidon_core.GridGenerator(
    file_path,
    min_x_extent,
    max_x_extent,
    min_y_extent,
    max_y_extent,
    lidar_units="feet",
)

resolution = 0.05  # meters

pts_array = grid_gen.create_point_array()
grid_x, grid_y, grid_z = grid_gen.gen_grid(
    resolution, pts_array, grid_descriptor="carolina_beach"
)

# %%
# Visualize the elevation grid
grid_gen.plot_elev_grid(grid_z)

# %% [markdown]
# ### Image Rectification

# %%
intrinsics = np.array(
    [
        3040,  # number of pixel columns
        4056,  # number of pixel rows
        1503.0136,  # U component of principal point
        2163.4301,  # V component of principal point
        2330.4972,  # U component of focal length
        2334.0017,  # V component of focal length
        -0.3587,  # radial distortion
        0.1388,  # radial distortion
        -0.0266,  # radial distortion
        -0.0046,  # tangential distortion
        0.0003,  # tangential distortion
    ]
)

# extrinsics = np.array([847955.4296, # camera x in world
#                        127408.728, # camera y in world
#                        4.4922, # camera elev in world
#                        4.38504, # azimuth
#                        1.14484, # tilt
#                        0.01305 # roll/swing
#                        ])
extrinsics = np.array(
    [
        712159.597863065,  # camera x in world
        33136.9994153273,  # camera y in world
        3.72446811607855,  # camera elev in world
        1.30039127961854,  # azimuth
        1.02781393967485,  # tilt
        -0.160877893129538,  # roll/swing
    ]
)

# %%
rectifier = poseidon_core.ImageRectifier(
    intrinsics, extrinsics, grid_x, grid_y, grid_z, use_gpu=True
)

rect_im = rectifier.merge_rectify(
    "data/CAM_DE_01_20241020151826.jpg", verbose=True
)

# %%
rectifier.merge_rectify_folder(
    "data/flood_events/CB_03_20231002131313_20231002203713/labels",
    "data/flood_events/CB_03_20231002131313_20231002203713/zarr/labels",
    labels=True,

# %% [markdown]
# ### Depth Map Processing

# %%
processor = poseidon_core.DepthMapProcessor(
    grid_z,
    pond_edge_elev_plot_dir="data/flood_events/CB_03_20231002131313_20231002203713/plots",
)

# %%
processor.process_depth_maps(
    "data/flood_events/CB_03_20231002131313_20231002203713/zarr/labels",
    "data/flood_events/CB_03_20231002131313_20231002203713/zarr/depth_maps",
)

# %% [markdown]
# ### Depth Map Plotting

# %%
main_dir = "data/flood_events"

# virtual_sensor_locs = np.array([[3174, 2691], [1900, 1657], [2362, 2092]])
virtual_sensor_locs = np.array([[125, 390], [75, 440], [5, 370], [9, 355]]) * 2

# min_x_extent = 847809.694
# max_x_extent = 847973.874
# min_y_extent = 127254.634
# max_y_extent = 127450.141
min_x_extent = 712160
max_x_extent = 712230
min_y_extent = 33100
max_y_extent = 33170

plotter = poseidon_core.DepthMapPlotter(
    main_dir,
    min_x_extent,
    max_x_extent,
    min_y_extent,
    max_y_extent,
    bbox_crs="EPSG:32119",
    virtual_sensor_locations=virtual_sensor_locs,
    plot_sensors=True,
)

# %%
plotter.process_single_flood_event(
    "CB_03_20231002131313_20231002203713", ["95_perc"]
)

# plotter.preprocess_flood_events()

# %%
plotter.preprocess_flood_events()
flood_event_path = "data/flood_events/DE_01_20240921105956_20240921231819"

plotter.plot_water_level_time_series(
    "CAM_DE_01_20240921203026.jpg",
    flood_event_path,
    "data/flood_events/DE_01_20240921105956_20240921231819/time_series",
)

# %%
flood_event_path = "data/flood_events/CB_03_20231002131313_20231002203713"

for filename in os.listdir(
    "data/flood_events/CB_03_20231002131313_20231002203713/orig_images"
):
    plotter.plot_water_level_time_series(
        filename,
        flood_event_path,
        "data/flood_events/CB_03_20231002131313_20231002203713/time_series_using_depths",
    )
